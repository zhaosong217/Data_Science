# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# %%
df = pd.read_csv('/Users/songzhao/Code Playground/xl/SL_Analysis_preprocess.csv')
df.head()
# Out:
#    Unnamed: 0        Date   Time           From                  To  \
# 0           0  2025.01.23  15:22  Östra station          Banérgaten
# 1           1  2025.01.23  14:48     Bergshamra  Tekniska högskolen
# 2           2  2025.01.23  14:23    T-centralen          Bergshamra
# 3           3  2025.01.23  08:17  Östra station          Banérgaten
# 4           4  2025.01.22  14:44  Östra station          Banérgaten
#
#   Holiday Status Transport  Temperature Weather Status  Line1  Line2
# 0        Workday       Bus          2.0         Cloudy    4.0    NaN
# 1        Workday     Metro          2.0         Cloudy   14.0    NaN
# 2        Workday     Metro          2.0         Cloudy   14.0    NaN
# 3        Workday       Bus          2.0        Drizzle    4.0    NaN
# 4        Workday       Bus          3.0         Cloudy    4.0    NaN

# %%
df = df.drop(columns='Unnamed: 0')
df.head()
# Out:
#          Date   Time           From                  To Holiday Status  \
# 0  2025.01.23  15:22  Östra station          Banérgaten        Workday
# 1  2025.01.23  14:48     Bergshamra  Tekniska högskolen        Workday
# 2  2025.01.23  14:23    T-centralen          Bergshamra        Workday
# 3  2025.01.23  08:17  Östra station          Banérgaten        Workday
# 4  2025.01.22  14:44  Östra station          Banérgaten        Workday
#
#   Transport  Temperature Weather Status  Line1  Line2
# 0       Bus          2.0         Cloudy    4.0    NaN
# 1     Metro          2.0         Cloudy   14.0    NaN
# 2     Metro          2.0         Cloudy   14.0    NaN
# 3       Bus          2.0        Drizzle    4.0    NaN
# 4       Bus          3.0         Cloudy    4.0    NaN

# %%
df['From'].value_counts()
# Out:
# From
# Östra station         13
# Tekniska högskolen     6
# Banérgaten             4
# Karlaplan              4
# T-centralen            3
# Skanstull              3
# Stadsbiblioteket       2
# Bergshamra             1
# Östermalmstorg         1
# Värtavägen             1
# Flaminggatan           1
# Solna centrum          1
# Kungsträdgården        1
# Norrmalmstorg          1
# Arninge                1
# Name: count, dtype: int64

# %%
df_from = df['From'].value_counts()
df_from.plot(kind='bar',
             figsize=(10,8))
plt.show()

# %%
df_to = df['To'].value_counts()
df_to.plot(kind='bar',
           figsize=(10,8))
plt.show()
